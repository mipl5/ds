# %%
import pandas as pand

df = pand.read_csv('Solana Historical Data.csv')

#print(df)
#print(df.to_string())
#display(df)
datePrice = df[['Date','Price']]
#display(datePrice)
sum_of_prices = df['Price'].sum()

avg_of_prices = df['Price'].mean()
print(f"Avg: {avg_of_prices} $ (U.S.D.)")

max_of_prices = df['Price'].max()
min_of_prices = df['Price'].min()

print(f"Max:{max_of_prices} / Min: {min_of_prices}")

print(sum_of_prices)
sumChange = df['Open'].sum()
print(sumChange)
# Out:
# Avg: 52.51088188188188 $ (U.S.D.)
# Max:258.477 / Min: 1.004
# 52458.371
# 52418.846000000005

# %%
print(pand.__version__)
# Out:
# 2.1.4

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

x = np.linspace(0, 2 * np.pi, 200)
y = np.tan(x)

fig, ax = plt.subplots()
ax.plot(x,y, linewidth = 2.0)
#ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       #ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Solana Historical Data.csv')
df.plot(x='Date', y = 'Price')
plt.show()
plt.figure(figure.size(100,11000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 df.plot(x='Date', y = 'Price')
#       6 plt.show()
# ----> 7 plt.figure(figure.size(100,11000))
#
# NameError: name 'figure' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('BrentOilPrices.csv')
max_df = df['Price'].max()
print(max_df)
min_df = df['Price'].min()
print(min_df)
df.plot(x='Date', y = 'Price')
plt.show()
plt.figure(figure.size(100,11000))
# Out:
# 143.95
# 9.1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       9 df.plot(x='Date', y = 'Price')
#      10 plt.show()
# ---> 11 plt.figure(figure.size(100,11000))
#
# NameError: name 'figure' is not defined

# %%
import pandas
import plotly.express as px

#df = pandas.read_csv('Solana Historical Data.csv')
#fg = px.line(df, x = 'Date', y = 'Price', title = 'Solana Rec')

import pandas as pd
import plotly.graph_objects as go

df = pd.read_csv('Solana Historical Data.csv')

fig = go.Figure(go.Scatter(x = df['Date'], y = df['Price'],
                  name='Share Prices (in USD)'))

fig.update_layout(title='Solana Rec',
                   plot_bgcolor='rgb(230, 230,230)',
                   showlegend=True)

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with fig.show()"
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 6
#       1 import plotly.graph_objects as go
#       2 fig = go.Figure(
#       3     data=[go.Bar(y=[2, 1, 3])],
#       4     layout_title_text="A Figure Displayed with fig.show()"
#       5 )
# ----> 6 fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# ...
